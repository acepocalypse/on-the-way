# %%
import requests
import google.generativeai as genai

genai.configure(api_key="AIzaSyBzhJig2EgnHA_yrOX0pW_pdkKlFdqjGfY")
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
# Step 1: Gather Inputs
start_location = "Denver, CO"
end_location = "Las Vegas, NV"
travel_date_start = "2025-03-14"
travel_date_ends = "2025-03-21"
preferences = ["hiking", "scenic drives", "budget-friendly"]

# Step 2: Get Road Trip Recommendations (AI + Map API)
def get_route_recommendations(start, end, interests):
    # Use Google Maps API for routing
    route_api_url = f"https://maps.googleapis.com/maps/api/directions/json"
    params = {
        "origin": start,
        "destination": end,
        "key": "AIzaSyA63OBpKtps7DCapnYEdQ7kaIQhNeVNBeM"
    }
    response = requests.get(route_api_url, params=params)
    route_data = response.json()

    if route_data["status"] == "OK":
        leg = route_data["routes"][0]["legs"][0]  # Access the first route and its first leg
        distance = leg["distance"]["text"]  # Distance in human-readable format (e.g., "5.3 km")
        duration = leg["duration"]["text"]  # Duration in human-readable format (e.g., "12 mins")

        print(f"Distance: {distance}")
        print(f"Drive Time: {duration}")
    else:
        print(f"Error: {route_data['status']}")
    
    # Use AI (e.g., OpenAI) for personalized suggestions
    prompt = f"Suggest fun stops for a road trip from {start} to {end} based on interests: {', '.join(interests)}."
    ai_response = model.generate_content(prompt)

    return ai_response.text

road_trip_stops = get_route_recommendations(start_location, end_location, preferences)
print("Road Trip Recommendations:", road_trip_stops)

# Step 3: Search for Flights
# def search_flights(origin, destination, date):
#     flight_api_url = "https://partners.api.skyscanner.net/apiservices/browseroutes/v1.0/US/USD/en-US/"
#     api_key = "YOUR_SKYSCANNER_API_KEY"
#     response = requests.get(f"{flight_api_url}{origin}/{destination}/{date}", params={"apiKey": api_key})
#     return response.json()

# flights = search_flights("IND", "DEN", travel_date)
# print("Flight Options:", flights)
# Out:
# Distance: 749 mi
# Drive Time: 10 hours 49 mins
# Road Trip Recommendations: ## Denver to Las Vegas Road Trip: Hiking, Scenic Drives & Budget-Friendly Fun
#
# This itinerary prioritizes budget-friendly options and balances hiking with scenic drives.  Driving times are estimates and can vary. Adjust based on your preferences and pace.
#
# **Day 1: Denver to Grand Junction, CO (approx. 4-5 hours driving)**
#
# * **Scenic Drive:** Take I-70 West.  The initial part offers stunning views of the Colorado Rockies.  Consider a short detour to **Red Rocks Amphitheatre** (entrance fee applies, but worth it if you have time) for photos and a glimpse of the iconic venue.
# * **Budget-Friendly Activity:** Pack a picnic lunch to enjoy amidst the scenery.  Grand Junction has several affordable grocery stores for supplies.
# * **Budget-Friendly Accommodation:** Look for motels or budget-friendly hotels in Grand Junction.
#
# **Day 2: Grand Junction to Moab, UT (approx. 3-4 hours driving)**
#
# ...
